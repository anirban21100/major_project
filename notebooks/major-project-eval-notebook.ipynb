# %%
# !pip install split-folders

# %%
import sys
sys.path.append('/kaggle/input/major-project-code/main_folder/')

# %%
import warnings
warnings.filterwarnings("ignore")
import shutil
import numpy as np
import splitfolders
from tqdm import tqdm
from tensorflow.keras.models import load_model
from code_base.data_pps.datagenffd import PreprocessData
# from keras._tf_keras.keras.preprocessing.image import ImageDataGenerator

# %%
COLS = 224
ROWS = 224
CHANS = 3
NUM_CLASSES = 15
# DIR = '/kaggle/input/human-activity-recognition-train-and-test-folders/HAR'
EVAL_DIR = '/kaggle/input/human-activity-recognition-train-and-test-folders/HAR/test'

# %%
shutil.copytree(EVAL_DIR, '/kaggle/working/test/test_images')
# Out:
# '/kaggle/working/test/test_images'

# %%
 for _ in tqdm(range(1)):
     test_gen = PreprocessData.transform(
                        DIR = '/kaggle/working/test',
                        batch_size = 1,
                        shuffle = False,
                        class_mode=None
                        )
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Found 5410 images belonging to 1 classes.
# 100%|██████████| 1/1 [00:00<00:00, 12.03it/s]

# %%
test_gen.__len__()
# Out:
# 5410

# %%
model = load_model('/kaggle/input/diat_har_vanilla/keras/default/1/model_DIAT_HAR_vanilla.keras')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
pred = model.predict(test_gen)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 5410/5410 ━━━━━━━━━━━━━━━━━━━━ 24s 4ms/step

# %%
np.save('pred.npy', pred)
